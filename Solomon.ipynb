# %% [markdown]
# ---
# ### *INFORMATION*
# ---
# ### *NAME:BAAH SOLOMON*
# ---
# ### *INDEX NUMBER:11358187*
# ---
# ### *CLASS:BIOMEDICAL ENGINEERING *
# ---

# %% [markdown]
# __*importing pandas as pd*__

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.1.4

# %% [markdown]
#  __*importing numpy as np*__

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.26.3

# %% [markdown]
# __*importing matplotlib as plt*__

# %%
import matplotlib.pyplot as plt

# %% [markdown]
#  __*importing data from csv file*__

# %%
dataset = pd.read_csv('red_wine.csv')

# %% [markdown]
#  __*view data*__

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %% [markdown]
#  __*check head --- Return first 10 rows of the dataset*__

# %%
dataset.head(10)
# the head method displays the first 5 rows of the dataframe
#data.head(10)--- to show first 10 rows-----thus by specification
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# 3      9.8      6.0
# 4      9.4      5.0
# 5      9.4      5.0
# 6      9.4      5.0
# 7     10.0      7.0
# 8      9.5      7.0
# 9     10.5      5.0

# %% [markdown]
#  __*check tail --- Return last 20 rows of the dataset*__

# %%
dataset.tail(20)
# data.tail() --- by default returns the last five rows of the data
# but can be changed by specification as shown above
# eg. data.tail(10)--- to show last 10 rows
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1579     11.3      5.0
# 1580     11.9      6.0
# 1581     11.3      5.0
# 1582     11.9      5.0
# 1583      9.8      5.0
# 1584     11.6      7.0
# 1585     11.5      6.0
# 1586     11.4      6.0
# 1587     10.9      6.0
# 1588     12.8      6.0
# 1589      9.2      5.0
# 1590     11.6      6.0
# 1591     11.6      6.0
# 1592     11.0      6.0
# 1593      9.5      6.0
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0

# %% [markdown]
#  __*check info --- basic information on the dataset*__

# %%
dataset.info()

# data info --- refers to  the data size or structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# __*remove all null values --- dropna method*__

# %%
# the dropna() method removes all null values from the dataset

# %% [markdown]
#  __*fillna method fills the null set with data based on your command*__

# %%
# A = original_dataset['fixed acidity'].mean() 
# original_dataset['fixed acidity']=original_dataset['fixed acidity'].fillna(A)
# so with this it fills the null sets in the fixed acidity with the mean of all the fixed acidities

# %%
complete_data = dataset.dropna()
complete_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1590 rows x 12 columns]

# %%
original_dataset = pd.read_csv('red_wine.csv')

# %%
original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %% [markdown]
# -----------------------------
# ### *Replacing null values with mean*
# -----------------------------

# %%
A = original_dataset['fixed acidity'].mean()

# %%
B = original_dataset['volatile acidity'].mean()

# %%
C = original_dataset['chlorides'].mean()

# %%
D = original_dataset['free sulfur dioxide'].mean()

# %%
E = original_dataset['density'].mean()

# %%
F = original_dataset['quality'].mean()

# %%
original_dataset['fixed acidity']=original_dataset['fixed acidity'].fillna(A)

# %%
original_dataset['volatile acidity']=original_dataset['volatile acidity'].fillna(B)

# %%
original_dataset['chlorides']=original_dataset['chlorides'].fillna(C)

# %%
original_dataset['free sulfur dioxide']= original_dataset['free sulfur dioxide'].fillna(D)

# %%
original_dataset['density']= original_dataset['density'].fillna(E)

# %%
original_dataset['quality']=original_dataset['quality'].fillna(F)

# %%
original_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4      5.0
# 1         9.8      5.0
# 2         9.8      5.0
# 3         9.8      6.0
# 4         9.4      5.0
# ...       ...      ...
# 1594     10.5      5.0
# 1595     11.2      6.0
# 1596     11.0      6.0
# 1597     10.2      5.0
# 1598     11.0      6.0
#
# [1599 rows x 12 columns]

# %%
original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# ###
# --------------------------------
# #### *BASIC GRAPHS FOR DEMONSTRATION*
# --------------------------------

# %% [markdown]
# ###
# -------------------------------------------------------------------
# ##### *GRAPHICAL REPRESENTATION OF THE NUMERICAL(DATA) AS DISCUSSED ABOVE*
# -------------------------------------------------------------------

# %%
graph = original_dataset[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]

# %%
plt.plot(graph)
# Out:
# [<matplotlib.lines.Line2D at 0x20bf64b13a0>,
#  <matplotlib.lines.Line2D at 0x20bf64b13d0>,
#  <matplotlib.lines.Line2D at 0x20bf64b14c0>,
#  <matplotlib.lines.Line2D at 0x20bf64b15b0>,
#  <matplotlib.lines.Line2D at 0x20bf64b16a0>,
#  <matplotlib.lines.Line2D at 0x20bf6432f90>,
#  <matplotlib.lines.Line2D at 0x20bf64b1790>,
#  <matplotlib.lines.Line2D at 0x20bf64b1940>,
#  <matplotlib.lines.Line2D at 0x20bf64b1a30>,
#  <matplotlib.lines.Line2D at 0x20bf6431df0>,
#  <matplotlib.lines.Line2D at 0x20bf64b1b20>,
#  <matplotlib.lines.Line2D at 0x20bf64b1cd0>]

# %% [markdown]
# ### _*GENERATING RANDOM DATA FOR  DEMONSTRATION*_

# %% [markdown]
# ## creating histogram for the dataset

# %%
original_dataset = np.random.randn(1000)
plt.hist(original_dataset, bins=20, edgecolor='red')

# Add titles and labels
plt.xlabel('column')
plt.ylabel('frequency')
plt.title('Histogram from the original dataset')
# view my plot
plt.show()

# %% [markdown]
# #### ---
# *The two above graphs were obtained from the original_dataset*
# ---

# %% [markdown]
# ### summary
# #### *This home-based task demonstrates proficiency in utilizing Jupyter Notebooks and Python modules for effective data analysis, statistical exploration, and applications of machine learning. The visualizations provide meaningful insights into the dataset, showcasing the interactive capabilities of Jupyter widgets.*
#
# #### *Feel free to dive into the repository's Jupyter Notebooks for a more thorough examination of the analyses and visual content. Should you have any questions or feedback, don't hesitate to get in touch!*
#
# #### *Wishing you a rewarding exploration!*
